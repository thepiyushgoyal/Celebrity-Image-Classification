# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./dataset/TomCruise/1.jpg')
img.shape
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (576, 474)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[135, 126, 180, 180]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (135, 126, 180, 180)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (180, 180, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/HughJackman',
#  './dataset/JohnnyDepp',
#  './dataset/LeonardoDiCaprio',
#  './dataset/RobertDowneyJr',
#  './dataset/TomCruise']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# cropped
# HughJackman
# Generating cropped images in folder:  ./dataset/cropped/HughJackman
# JohnnyDepp
# Generating cropped images in folder:  ./dataset/cropped/JohnnyDepp
# LeonardoDiCaprio
# Generating cropped images in folder:  ./dataset/cropped/LeonardoDiCaprio
# RobertDowneyJr
# Generating cropped images in folder:  ./dataset/cropped/RobertDowneyJr
# TomCruise
# Generating cropped images in folder:  ./dataset/cropped/TomCruise

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'HughJackman': ['./dataset/cropped/HughJackman\\HughJackman1.png',
#   './dataset/cropped/HughJackman\\HughJackman10.png',
#   './dataset/cropped/HughJackman\\HughJackman11.png',
#   './dataset/cropped/HughJackman\\HughJackman12.png',
#   './dataset/cropped/HughJackman\\HughJackman13.png',
#   './dataset/cropped/HughJackman\\HughJackman14.png',
#   './dataset/cropped/HughJackman\\HughJackman15.png',
#   './dataset/cropped/HughJackman\\HughJackman16.png',
#   './dataset/cropped/HughJackman\\HughJackman17.png',
#   './dataset/cropped/HughJackman\\HughJackman18.png',
#   './dataset/cropped/HughJackman\\HughJackman19.png',
#   './dataset/cropped/HughJackman\\HughJackman2.png',
#   './dataset/cropped/HughJackman\\HughJackman20.png',
#   './dataset/cropped/HughJackman\\HughJackman21.png',
#   './dataset/cropped/HughJackman\\HughJackman22.png',
#   './dataset/cropped/HughJackman\\HughJackman23.png',
#   './dataset/cropped/HughJackman\\HughJackman24.png',
#   './dataset/cropped/HughJackman\\HughJackman25.png',
#   './dataset/cropped/HughJackman\\HughJackman26.png',
#   './dataset/cropped/HughJackman\\HughJackman27.png',
#   './dataset/cropped/HughJackman\\HughJackman28.png',
#   './dataset/cropped/HughJackman\\HughJackman29.png',
#   './dataset/cropped/HughJackman\\HughJackman3.png',
#   './dataset/cropped/HughJackman\\HughJackman30.png',
#   './dataset/cropped/HughJackman\\HughJackman31.png',
#   './dataset/cropped/HughJackman\\HughJackman32.png',
#   './dataset/cropped/HughJackman\\HughJackman33.png',
#   './dataset/cropped/HughJackman\\HughJackman34.png',
#   './dataset/cropped/HughJackman\\HughJackman35.png',
#   './dataset/cropped/HughJackman\\HughJackman36.png',
#   './dataset/cropped/HughJackman\\HughJackman37.png',
#   './dataset/cropped/HughJackman\\HughJackman38.png',
#   './dataset/cropped/HughJackman\\HughJackman39.png',
#   './dataset/cropped/HughJackman\\HughJackman4.png',
#   './dataset/cropped/HughJackman\\HughJackman40.png',
#   './dataset/cropped/HughJackman\\HughJackman41.png',
#   './dataset/cropped/HughJackman\\HughJackman42.png',
#   './dataset/cropped/HughJackman\\HughJackman43.png',
#   './dataset/cropped/HughJackman\\HughJackman44.png',
#   './dataset/cropped/HughJackman\\HughJackman45.png',
#   './dataset/cropped/HughJackman\\HughJackman46.png',
#   './dataset/cropped/HughJackman\\HughJackman47.png',
#   './dataset/cropped/HughJackman\\HughJackman48.png',
#   './dataset/cropped/HughJackman\\HughJackman49.png',
#   './dataset/cropped/HughJackman\\HughJackman5.png',
#   './dataset/cropped/HughJackman\\HughJackman50.png',
#   './dataset/cropped/HughJackman\\HughJackman51.png',
#   './dataset/cropped/HughJackman\\HughJackman52.png',
#   './dataset/cropped/HughJackman\\HughJackman53.png',
#   './dataset/cropped/HughJackman\\HughJackman54.png',
#   './dataset/cropped/HughJackman\\HughJackman55.png',
#   './dataset/cropped/HughJackman\\HughJackman56.png',
#   './dataset/cropped/HughJackman\\HughJackman57.png',
#   './dataset/cropped/HughJackman\\HughJackman58.png',
#   './dataset/cropped/HughJackman\\HughJackman59.png',
#   './dataset/cropped/HughJackman\\HughJackman6.png',
#   './dataset/cropped/HughJackman\\HughJackman60.png',
#   './dataset/cropped/HughJackman\\HughJackman61.png',
#   './dataset/cropped/HughJackman\\HughJackman62.png',
#   './dataset/cropped/HughJackman\\HughJackman63.png',
#   './dataset/cropped/HughJackman\\HughJackman64.png',
#   './dataset/cropped/HughJackman\\HughJackman65.png',
#   './dataset/cropped/HughJackman\\HughJackman66.png',
#   './dataset/cropped/HughJackman\\HughJackman67.png',
#   './dataset/cropped/HughJackman\\HughJackman68.png',
#   './dataset/cropped/HughJackman\\HughJackman69.png',
#   './dataset/cropped/HughJackman\\HughJackman7.png',
#   './dataset/cropped/HughJackman\\HughJackman8.png',
#   './dataset/cropped/HughJackman\\HughJackman9.png'],
#  'JohnnyDepp': ['./dataset/cropped/JohnnyDepp\\JohnnyDepp1.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp10.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp11.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp12.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp13.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp14.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp15.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp16.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp17.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp18.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp19.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp2.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp20.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp21.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp22.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp23.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp24.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp25.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp26.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp27.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp28.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp29.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp3.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp30.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp31.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp32.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp33.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp34.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp35.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp36.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp37.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp38.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp39.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp4.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp40.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp41.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp42.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp43.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp44.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp45.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp46.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp47.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp48.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp49.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp5.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp50.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp51.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp52.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp53.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp54.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp6.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp7.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp8.png',
#   './dataset/cropped/JohnnyDepp\\JohnnyDepp9.png'],
#  'LeonardoDiCaprio': ['./dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio1.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio10.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio11.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio12.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio13.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio14.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio15.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio16.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio17.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio18.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio19.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio2.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio20.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio21.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio22.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio23.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio24.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio25.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio26.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio27.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio28.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio29.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio3.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio30.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio31.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio32.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio33.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio34.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio35.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio36.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio37.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio38.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio39.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio4.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio40.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio41.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio42.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio43.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio44.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio45.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio46.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio47.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio48.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio49.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio5.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio50.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio51.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio52.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio53.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio54.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio55.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio56.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio57.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio58.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio59.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio6.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio60.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio61.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio62.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio63.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio64.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio65.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio66.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio67.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio68.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio69.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio7.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio70.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio71.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio72.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio73.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio74.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio75.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio76.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio77.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio78.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio79.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio8.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio80.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio81.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio82.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio83.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio84.png',
#   './dataset/cropped/LeonardoDiCaprio\\LeonardoDiCaprio9.png'],
#  'RobertDowneyJr': ['./dataset/cropped/RobertDowneyJr\\RobertDowneyJr1.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr10.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr11.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr12.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr13.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr14.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr15.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr16.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr17.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr18.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr19.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr2.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr20.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr21.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr22.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr23.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr24.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr25.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr26.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr27.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr28.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr29.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr3.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr30.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr31.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr32.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr33.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr34.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr35.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr36.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr37.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr38.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr39.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr4.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr40.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr41.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr42.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr43.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr44.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr45.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr46.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr47.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr48.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr49.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr5.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr50.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr51.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr52.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr53.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr54.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr55.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr56.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr57.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr58.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr59.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr6.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr60.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr7.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr8.png',
#   './dataset/cropped/RobertDowneyJr\\RobertDowneyJr9.png'],
#  'TomCruise': ['./dataset/cropped/TomCruise\\TomCruise1.png',
#   './dataset/cropped/TomCruise\\TomCruise10.png',
#   './dataset/cropped/TomCruise\\TomCruise11.png',
#   './dataset/cropped/TomCruise\\TomCruise12.png',
#   './dataset/cropped/TomCruise\\TomCruise13.png',
#   './dataset/cropped/TomCruise\\TomCruise14.png',
#   './dataset/cropped/TomCruise\\TomCruise15.png',
#   './dataset/cropped/TomCruise\\TomCruise16.png',
#   './dataset/cropped/TomCruise\\TomCruise17.png',
#   './dataset/cropped/TomCruise\\TomCruise18.png',
#   './dataset/cropped/TomCruise\\TomCruise19.png',
#   './dataset/cropped/TomCruise\\TomCruise2.png',
#   './dataset/cropped/TomCruise\\TomCruise20.png',
#   './dataset/cropped/TomCruise\\TomCruise21.png',
#   './dataset/cropped/TomCruise\\TomCruise22.png',
#   './dataset/cropped/TomCruise\\TomCruise23.png',
#   './dataset/cropped/TomCruise\\TomCruise24.png',
#   './dataset/cropped/TomCruise\\TomCruise25.png',
#   './dataset/cropped/TomCruise\\TomCruise26.png',
#   './dataset/cropped/TomCruise\\TomCruise27.png',
#   './dataset/cropped/TomCruise\\TomCruise28.png',
#   './dataset/cropped/TomCruise\\TomCruise29.png',
#   './dataset/cropped/TomCruise\\TomCruise3.png',
#   './dataset/cropped/TomCruise\\TomCruise30.png',
#   './dataset/cropped/TomCruise\\TomCruise31.png',
#   './dataset/cropped/TomCruise\\TomCruise32.png',
#   './dataset/cropped/TomCruise\\TomCruise33.png',
#   './dataset/cropped/TomCruise\\TomCruise34.png',
#   './dataset/cropped/TomCruise\\TomCruise35.png',
#   './dataset/cropped/TomCruise\\TomCruise36.png',
#   './dataset/cropped/TomCruise\\TomCruise37.png',
#   './dataset/cropped/TomCruise\\TomCruise38.png',
#   './dataset/cropped/TomCruise\\TomCruise39.png',
#   './dataset/cropped/TomCruise\\TomCruise4.png',
#   './dataset/cropped/TomCruise\\TomCruise40.png',
#   './dataset/cropped/TomCruise\\TomCruise41.png',
#   './dataset/cropped/TomCruise\\TomCruise42.png',
#   './dataset/cropped/TomCruise\\TomCruise43.png',
#   './dataset/cropped/TomCruise\\TomCruise44.png',
#   './dataset/cropped/TomCruise\\TomCruise45.png',
#   './dataset/cropped/TomCruise\\TomCruise46.png',
#   './dataset/cropped/TomCruise\\TomCruise47.png',
#   './dataset/cropped/TomCruise\\TomCruise48.png',
#   './dataset/cropped/TomCruise\\TomCruise49.png',
#   './dataset/cropped/TomCruise\\TomCruise5.png',
#   './dataset/cropped/TomCruise\\TomCruise50.png',
#   './dataset/cropped/TomCruise\\TomCruise51.png',
#   './dataset/cropped/TomCruise\\TomCruise52.png',
#   './dataset/cropped/TomCruise\\TomCruise53.png',
#   './dataset/cropped/TomCruise\\TomCruise54.png',
#   './dataset/cropped/TomCruise\\TomCruise55.png',
#   './dataset/cropped/TomCruise\\TomCruise56.png',
#   './dataset/cropped/TomCruise\\TomCruise57.png',
#   './dataset/cropped/TomCruise\\TomCruise58.png',
#   './dataset/cropped/TomCruise\\TomCruise59.png',
#   './dataset/cropped/TomCruise\\TomCruise6.png',
#   './dataset/cropped/TomCruise\\TomCruise7.png',
#   './dataset/cropped/TomCruise\\TomCruise8.png',
#   './dataset/cropped/TomCruise\\TomCruise9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'HughJackman': 0,
#  'JohnnyDepp': 1,
#  'LeonardoDiCaprio': 2,
#  'RobertDowneyJr': 3,
#  'TomCruise': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (326, 4096)

# %% [markdown]
# # Trainin

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, LSTM, SimpleRNN

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)

# model = Sequential()
# model.add(LSTM(128, activation='relu', return_sequences=True))
# model.add(LSTM(128, activation='relu'))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(10, activation='softmax'))
# model.compile(optimizer='adam',
#     loss='sparse_categorical_crossentropy',
#     metrics=['accuracy'],
# )
# model.fit(X_train,
#           y_train,
#           epochs=3)
# model.score(X_test, y_test)
# Out:
# 0.6829268292682927

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.57      0.70        23
#            1       0.57      0.67      0.62        12
#            2       0.70      0.84      0.76        19
#            3       0.59      0.59      0.59        17
#            4       0.64      0.82      0.72        11
#
#     accuracy                           0.68        82
#    macro avg       0.69      0.70      0.68        82
# weighted avg       0.71      0.68      0.68        82

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.680102
# 1        random_forest    0.389116
# 2  logistic_regression    0.675935
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.6707317073170732

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7560975609756098

# %%
best_clf = best_estimators['logistic_regression']

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\piyus\python312\lib\site-packages (1.3.2)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
